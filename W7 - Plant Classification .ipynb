# %% [markdown]
# ## Instructions:
# * Step 1 - Download the soybean dataset here
# * Step 2 - Build a neural network using numpy (no libraries) ,
# ** train it on the dataset, and
# ** show 2 examples of it testing on test crop images.
#
# This should all go inside of a jupyter notebook
#
# ***NOTE***
#
# If you find it too difficult to build  a neural network from scratch, then and only then,
# look at https://www.kaggle.com/datduyn/2-layer-net-on-weeds-discriminant/
#
# If you still find it too difficult, you can use a library like Tensorflow+Keras.
#
# Bonus points if you use OpenCV for data preprocessing in someway

# %% [markdown]
# # NOTES
#
# * nice challenge to build NN from scratch
# * ended up basing my answer on the sample - and will look to revisit this challenge from scratch !
#
# * OpenCV would be a nice addition - and some sample references for followup
# [weed video](https://github.com/MrGrayCode/Weed-Detection/blob/master/weed_detection.py)
# ![weed](https://user-images.githubusercontent.com/15849927/41479326-687c7ce2-70e8-11e8-99d6-2aa9a5aaad41.png)
#
# [NN](https://github.com/ahmedbesbes/Neural-Network-from-scratch)
#
# ![NN](https://github.com/ahmedbesbes/Neural-Network-from-scratch/raw/master/images/backprop.gif)

# %% [markdown]
# Dataset :
#
# This image dataset has 15336 segments, being 3249 of soil, 7376 of soybean, 3520 grass and 1191 of broadleaf weeds

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import seaborn as sns # visualization
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1173.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1104.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/795.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1119.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/324.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/634.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/692.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/699.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/599.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/322.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/438.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/229.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/700.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/433.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1153.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/237.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1166.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/852.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/677.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/315.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/355.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/331.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/342.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1107.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/945.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/124.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/554.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/770.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/896.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/398.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/936.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/482.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/584.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/704.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/559.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/343.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/650.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/434.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/734.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/238.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/948.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1088.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/493.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/766.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/69.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/499.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1010.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/332.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/737.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/99.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/113.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/34.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1050.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/661.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1086.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/106.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/673.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/587.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1026.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/768.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/222.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/516.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/309.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/740.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/13.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/170.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/591.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/788.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/747.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/425.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/368.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/111.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/166.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/182.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/814.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/470.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/31.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/789.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/178.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/996.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/239.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/826.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1090.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/306.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/651.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/715.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/701.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/821.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1162.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/67.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/616.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/745.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1155.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1080.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/466.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/645.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/465.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/548.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1128.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1017.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/4.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/505.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/932.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/206.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/319.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/390.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/74.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/834.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/248.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/640.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1185.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/151.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/785.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/670.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/227.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/755.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1034.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/295.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/407.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/847.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1064.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/480.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/929.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/952.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/133.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/397.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/760.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/816.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/316.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/302.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1111.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/779.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/784.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/780.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/488.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/27.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/555.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/286.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/307.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/515.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/446.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/727.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/790.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/545.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/690.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/54.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/607.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/49.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/386.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/303.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/521.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/53.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/902.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/357.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/404.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/644.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/705.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/92.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/168.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/970.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/812.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/558.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1135.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/458.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/549.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/583.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/430.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/864.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/214.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/288.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/508.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1003.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/691.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/518.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/475.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/817.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/665.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/541.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/793.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/323.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/668.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/55.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/960.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/46.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/289.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/823.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/32.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/563.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1132.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1030.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/979.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/254.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/408.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/211.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/453.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/160.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/110.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1181.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/59.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/372.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/805.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/625.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/341.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/417.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/338.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/79.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/800.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/231.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1169.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/571.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/282.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/401.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/311.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/284.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/761.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1137.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/762.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/228.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/572.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1031.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/628.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/421.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/949.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/107.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/64.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/856.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/147.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/477.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1117.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1105.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/432.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/566.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/674.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1100.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/849.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/641.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1182.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/241.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/946.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1091.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1150.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1069.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/921.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/403.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/687.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/310.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/242.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/68.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/234.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/726.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1066.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/688.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/449.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/349.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1035.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1170.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/392.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1084.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1059.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/406.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/976.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/154.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/42.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/459.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/436.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/900.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/832.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/809.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/940.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/95.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/512.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/916.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/748.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/175.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1071.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/533.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/965.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/732.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1014.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/831.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/270.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/594.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/501.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/579.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/15.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/680.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/529.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/262.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/836.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/618.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/905.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/98.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1098.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/265.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/77.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/881.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/667.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/363.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/803.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/635.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/136.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1005.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/638.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/132.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/174.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1176.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/377.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/291.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/828.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/364.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/919.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/199.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/694.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/243.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/153.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1116.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/119.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/781.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/897.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/212.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/663.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/374.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/736.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/589.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/273.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/334.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/977.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/564.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1180.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/129.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/321.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/544.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/845.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/639.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/462.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/898.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/723.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1125.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/290.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/695.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/347.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/857.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/188.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/447.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/848.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1187.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/245.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/337.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1188.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/108.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/186.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/195.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/815.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/719.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/870.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/547.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/37.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1072.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/980.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1038.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/528.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/844.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1186.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1189.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1018.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/202.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/492.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/973.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/94.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/714.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/445.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/161.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/585.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/233.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/112.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/648.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/207.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/924.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/260.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/75.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/216.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1124.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/943.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/183.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/102.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1002.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1032.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/860.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/264.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/606.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/78.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/577.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/649.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/964.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/351.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/829.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/842.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/142.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/942.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1089.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/735.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/414.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/12.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1142.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/423.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/517.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/901.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/62.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/371.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/567.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/796.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/28.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/134.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/272.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/592.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/974.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/778.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1152.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/412.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/610.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/598.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/26.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/703.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/305.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/35.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/963.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/922.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/783.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/450.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/775.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/498.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/712.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/454.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/65.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/442.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/162.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/169.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/791.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/252.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1106.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/7.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/418.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/612.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/522.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/104.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/47.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1025.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/600.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/837.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/156.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/863.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/435.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/460.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/889.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/995.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/868.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/150.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1007.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/320.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/416.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/956.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/819.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/380.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/298.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/367.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1175.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/420.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/899.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/48.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1178.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/327.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/742.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/244.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/495.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/473.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1039.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/685.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/346.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/632.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/226.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/999.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/301.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/257.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/387.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/622.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/209.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/139.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/126.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1024.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1013.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/296.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/552.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/792.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/149.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/96.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/382.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/388.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/224.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/277.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1134.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/105.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/281.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/391.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1051.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/138.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/375.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/536.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/263.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/631.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/724.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/968.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1045.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1118.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/867.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1147.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/116.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/931.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/137.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/573.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/194.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/218.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/582.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/763.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1148.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/725.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/187.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1037.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/771.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/854.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/143.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/109.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/953.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/858.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1078.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/627.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/526.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/394.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/225.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1179.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/950.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/292.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/969.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/402.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/596.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/754.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/486.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/258.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/880.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/318.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/758.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/824.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/145.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/966.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/120.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/878.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/362.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1130.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1083.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/359.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/879.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/502.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1073.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/33.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/624.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/280.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1191.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/575.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1126.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/180.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/97.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/413.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/500.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/907.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/799.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/683.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/452.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/350.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/117.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1079.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/713.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/769.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/710.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1095.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/385.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1046.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/617.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/987.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/19.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/144.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/556.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/759.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1114.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/409.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/461.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/261.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/975.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/728.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/1057.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/broadleaf/531.tif
# ...
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2039.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1785.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/967.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/3383.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1754.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2973.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/657.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/72.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/3439.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2517.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2068.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/361.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1339.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/3474.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2186.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/3081.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2668.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2567.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1510.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1317.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2035.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1171.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1023.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1204.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/3088.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1441.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/205.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1967.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2725.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1662.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/3243.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1827.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1808.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/731.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1009.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/3369.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1966.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1657.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/992.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/797.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2259.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/3149.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1208.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2019.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1702.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1862.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1635.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/3239.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1001.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/738.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/662.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2362.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2772.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/184.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/994.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/339.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/3470.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/906.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2508.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/3518.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/259.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/3397.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1628.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/61.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1376.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/3304.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/3233.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1834.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/604.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1055.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/510.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2505.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/613.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/503.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2451.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2440.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1353.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1265.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1360.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/400.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/698.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/3091.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2945.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1004.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1489.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/3247.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2626.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/937.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1450.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/3094.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/509.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1893.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/730.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1285.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2743.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2678.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/3455.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/329.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2486.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/997.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/83.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1695.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1951.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1526.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2209.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2587.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/474.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1056.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2761.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/671.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/903.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1110.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2359.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/3378.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2021.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1817.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/551.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/3214.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2806.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1101.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2654.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/3360.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/961.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1652.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/652.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2947.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/3384.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/204.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1008.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/851.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2866.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/24.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2599.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1996.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1607.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2642.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2487.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/66.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2933.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/806.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/989.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1029.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/633.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2235.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2410.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1557.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2129.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/328.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/308.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/3440.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2372.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1760.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1428.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/87.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/249.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/753.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/464.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2292.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2702.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/215.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/679.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/373.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1122.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2632.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/615.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/741.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2431.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/859.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/954.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2090.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2536.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/3252.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/3001.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1438.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2700.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/250.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/379.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/619.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1190.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/3040.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2926.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1757.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1888.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1129.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2525.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/3115.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/335.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1910.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1692.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/3310.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2040.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1644.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2735.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1742.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/294.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1539.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/3105.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/511.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1937.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2297.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/3133.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1482.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/675.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/2241.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/537.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/3225.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/546.tif
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass/1077.tif

# %%
print(dirname)
# Out:
# /kaggle/input/weed-detection-in-soybean-crops/dataset/dataset/grass

# %%
from subprocess import check_output
print(check_output(["ls", "../input"]).decode("utf8"))
# Out:
# weed-detection-in-soybean-crops

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import cv2
import glob

# This is a bit of magic to make matplotlib figures appear inline in the notebook
# rather than in a new window.
# %matplotlib inline
plt.rcParams['figure.figsize'] = (19.0, 17.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data_dir = r'/kaggle/input/dataset/dataset/'
classes = ['broadleaf', 'grass', 'soil', 'soybean'] 

num_file = 1100 
all_files = [] 
num_data =num_file*len(classes)
Y = np.zeros(num_data)


for i, cls in enumerate(classes):
    all_files += [f for f in glob.glob(data_dir+cls+'/*.tif')][:num_file]
    Y[i*num_file:(i+1)*num_file] = i # label all classes with int [0.. len(classes)]

# %%
# Image dimension
im_width = 200
im_height = 200 
im_channel = 3
dim = im_width * im_height * im_channel

X = np.ndarray(shape=(num_data, im_width, im_height, im_channel), dtype=np.float64)

for idx, file in enumerate(all_files):
    X[idx] = cv2.resize(cv2.imread(file), (im_width, im_height))

X_train = np.empty(shape=(4000,im_width, im_height, im_channel), dtype=np.float64)
X_val = np.empty(shape=(200,im_width, im_height, im_channel), dtype=np.float64)
X_test = np.empty(shape=(200,im_width, im_height, im_channel), dtype=np.float64)

y_train = np.empty(4000)
y_val = np.empty(200)
y_test = np.empty(200) 

for i, cls in enumerate(classes): 
    X_test[50*i:50*(i+1)] = X[np.where(Y == i)[0][:50]]
    X_val[50*i:50*(i+1)] = X[np.where(Y == i)[0][50:100]]
    X_train[1000*i:1000*(i+1)] = X[np.where(Y == i)[0][100:]]
    
    y_test[50*i:50*(i+1)] = i
    y_val[50*i:50*(i+1)] = i
    y_train[1000*i:1000*(i+1)] = i
    
del Y 
del X

# Extract features 
#Shuffle training index
train_idxs = np.random.permutation(X_train.shape[0])
y_train  = y_train[train_idxs].astype(int)
X_train = X_train[train_idxs]

X_train = np.reshape(X_train, (X_train.shape[0], -1)).astype('float64')
X_test = np.reshape(X_test, (X_test.shape[0], -1)).astype('float64')
X_val = np.reshape(X_val, (X_val.shape[0], -1)).astype('float64')

X_tiny = X_train[100:110].astype('float64')
y_tiny = y_train[100:110].astype(int)
num_dev = 500

X_dev = X_train[0:num_dev].astype('float64')
y_dev = y_train[0:num_dev].astype(int)
print("X_train shape", X_train.shape, "| y_train shape:", y_train.shape)
print("X_test shape", X_test.shape, "| y_test shape:", y_test.shape)
print("X_val shape", X_val.shape, "| y_val shape:", y_val.shape)
print("X_dev shape", X_dev.shape, "| y_dev shape:", y_dev.shape)
print("X_tiny shape", X_tiny.shape, "| y_tiny shape:", y_tiny.shape)

#Subtract out the mean image 
#first: compute the mean image
# mean_image = np.mean(X_train, axis=0) #axis=0. stack horizontally
mean_image = 128
#Second subtract the mean image from train and test data 
X_train -= mean_image
X_val -= mean_image 
X_test -= mean_image
X_dev -= mean_image
X_tiny -= mean_image

#Third append the bias dimension using linear algebra trick
#Not for net
# X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
# X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
# X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
# X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
# X_tiny = np.hstack([X_tiny, np.ones((X_tiny.shape[0], 1))])

print('=====STACK BIAS term=====')
print("X_train shape", X_train.shape)
print("X_test shape", X_test.shape)
print("X_val shape", X_val.shape)
print("X_dev shape", X_dev.shape)
print("X_tiny shape", X_tiny.shape)
# Out:
# X_train shape (4000, 120000) | y_train shape: (4000,)
# X_test shape (200, 120000) | y_test shape: (200,)
# X_val shape (200, 120000) | y_val shape: (200,)
# X_dev shape (500, 120000) | y_dev shape: (500,)
# X_tiny shape (10, 120000) | y_tiny shape: (10,)
# =====STACK BIAS term=====
# X_train shape (4000, 120000)
# X_test shape (200, 120000)
# X_val shape (200, 120000)
# X_dev shape (500, 120000)
# X_tiny shape (10, 120000)

# %%
# Visualize some images 
# Make sure that everything when OK
classes = ['broadleaf', 'grass', 'soil', 'soybean']
n_class = len(classes)
samples_per_class = 4


for y, cls in enumerate(classes):
    idxes = np.flatnonzero(y == y_train)
    idxes = np.random.choice(idxes, samples_per_class, replace = False)
    for i, idx in enumerate(idxes):
        plt_idx = i * n_class + y + 1
        plt.subplot(samples_per_class,n_class, plt_idx)
        plt.imshow(X_train[idx].reshape(im_width, im_height, im_channel).astype('uint8'))
        if(i==0): plt.title(cls)

plt.show()

# %%
class TwoLayerNet():
    def __init__(self, input_size, hidden_size, output_size, std= 1e-4):
        '''
        std: weight initialization term
        W1: first layer weight, shape(D x H) 
        W2: second layer weight shape(H x C) 
        C: num_classes(output_size) , H: hidden_size, D: data_dim(input_size) 
        '''
        self.params = {}
        self.params['W1'] = std * np.random.randn(input_size, hidden_size)
        self.params['b1'] = np.zeros(hidden_size)
        self.params['W2'] = std * np.random.randn(hidden_size, output_size)
        self.params['b2'] = np.zeros(output_size)
        
    def loss(self, X, y = None, reg=0.0):
        '''
        reg: regularization strength
        X: ndarray shape(N x C). N: num of data 
        y: vector of training label
        '''
        #DEfine relu activation function 
        relu = lambda x:np.maximum(0,x)

        #unpack
        W1, b1 = self.params['W1'], self.params['b1']
        W2, b2 = self.params['W2'], self.params['b2']
        N, D = X.shape

        #Forward prop
        layer1 = relu(X.dot(W1) + b1)  #(N,D) x (D,H) = (N,H)
        scores = layer1.dot(W2) + b2

        #if target is not given then jump out 
        if(y is None): 
            return scores

        #compute the loss 
        ##Normalization trick to prevent overflow when compute exp 
        scores -= scores.max()#stack vertically

        scores = np.exp(scores)
        scores_sumexp = np.sum(scores, axis=1)#stack vertically

        ##Nomalize all score 
        softmax = scores / scores_sumexp.reshape(N,1)  #Shape: (N, C)
        #total loss of all training. -log of all correct score
        loss =  (-1.0) * np.sum(np.log(softmax[range(N),y]))

        ##Normalize the loss and add regularization strength 
        loss /= N 
        loss += reg * np.sum(W1 * W1) 
        loss += reg * np.sum(W2 * W2) 

        #Backward pass on the net 
        grads = {}

        correct_class_scores = scores[range(N), y]
        softmax[range(N), y] = (-1.0) * (scores_sumexp - correct_class_scores)/scores_sumexp
        softmax /= N


        #Want to find dW2(dL/dW2)
        # Derivation: dL/dW2 = dL/dscore * dscore/dW2(chain rule)
        #dL/dscore = softmax since L(score) = softmax(variable)
        #dscore/dW2 = relu_(hidden layer output)
        grads['W2'] = layer1.T.dot(softmax)
        grads['b2'] = np.sum(softmax, axis=0)#stack horizontally
        grads['W2'] += reg * 2 * W2

        #dL/dW1 = dL/dscore * dscore/drelu(layler1) * drelu(layer1)/dW1 
        #dL/dW1 = dW1 = softmax * W2 * X 
        hidden = softmax.dot(W2.T)

        #derivative of a max gate
        #Intuition: in forward pass if neuron didn't fire that mean. the derivative of that neuron 
        # is 0. This might be bad since this will kill gradient. 
        hidden[layer1 == 0] = 0 

        grads['W1'] = X.T.dot(hidden) 
        grads['b1'] = np.sum(hidden, axis=0) #stack horizontally 
        grads['W1'] += reg * 2 * W1

        return loss, grads

    def train(self, X, y, X_val, y_val, 
              learning_rate =1e-3, learning_rate_decay=0.95, 
              reg=5e-6, num_iters=100, 
              batch_size=200, it_verbose = 1, verbose=False):
        '''
        Train using SGD 
        Input: 
            X: nd array shape(N x D) 
            y: vector of train label 
            X_val: nd array shape( n_VAL , D) Use as validation set after each epoch 
            y_val: vector of validation label 
        '''
        N, D = X.shape
        N_val = X_val.shape[0]
        iteration_per_epoch = max(N/batch_size, 1)
        
        loss_hist = []
        train_acc_hist = []
        val_acc_hist = []
        
        for it in range(num_iters):
            sampling = np.random.choice(np.arange(N), batch_size, replace=False) 
            X_batch = X[sampling]
            y_batch = y[sampling]
            
            #compute loss and gradients
            loss, grads = self.loss(X_batch, y=y_batch, reg=reg)
            loss_hist.append(loss) 
            
            #Update rule 
            self.params['W1'] += (-1.0) * learning_rate * grads['W1']
            self.params['b1'] += (-1.0) * learning_rate * grads['b1']
            self.params['W2'] += (-1.0) * learning_rate * grads['W2']
            self.params['b2'] += (-1.0) * learning_rate * grads['b2']
            
            if(verbose and it%it_verbose==0):
                print('iteration: %d / %d | Loss: %f' % (it, num_iters, loss)) 
            # Every epoch, check train and val accuracy and decay learning rate.
            if (it % iteration_per_epoch == 0):
                # Check accuracy
                train_acc = (self.predict(X_batch) == y_batch).mean()
                val_acc = (self.predict(X_val) == y_val).mean()
                train_acc_hist.append(train_acc)
                val_acc_hist.append(val_acc)

                # Decay learning rate
                learning_rate *= learning_rate_decay
        return {
            'loss_hist':loss_hist,
            'train_acc_hist':train_acc_hist,
            'val_acc_hist':val_acc_hist
        }

    def predict(self, X):
        """
        Use the trained weights of this two-layer network to predict labels for
        data points. For each data point we predict scores for each of the C
        classes, and assign each data point to the class with the highest score.

        Inputs:
        - X: A numpy array of shape (N, D) giving N D-dimensional data points to
        classify.

        Returns:
        - y_pred: A numpy array of shape (N,) giving predicted labels for each of
        the elements of X. For all i, y_pred[i] = c means that X[i] is predicted
        to have class c, where 0 <= c < C.
        """
        y_pred = None
        relu = lambda x:np.maximum(0,x)
        # Unpack variables from the params dictionary
        W1, b1 = self.params['W1'], self.params['b1']
        W2, b2 = self.params['W2'], self.params['b2']

        #Forward propagation though the network 
        layer1 = relu(X.dot(W1) + b1)
        scores = layer1.dot(W2) + b2 #shape: (N x C)
        y_pred = np.argmax(scores, axis=1)

        return y_pred

# %%
input_size = im_width * im_height * im_channel
hidden_size = 200
output_size = n_class 
std = 1e-3 # size initialization parameter

net = TwoLayerNet(input_size, hidden_size,output_size,std )
stats = net.train(X_dev, y_dev, X_val, y_val, 
              learning_rate =1e-5, learning_rate_decay=0.95, 
              reg=0.0, num_iters=70, 
              batch_size=100, it_verbose = 10,verbose=True)
# Out:
# iteration: 0 / 70 | Loss: 1.505262
# iteration: 10 / 70 | Loss: 1.399308
# iteration: 20 / 70 | Loss: 1.389399
# iteration: 30 / 70 | Loss: 1.399704
# iteration: 40 / 70 | Loss: 1.417982
# iteration: 50 / 70 | Loss: 1.383059
# iteration: 60 / 70 | Loss: 1.387414

# %%
# plot loss history and train/ validation accuracies history
plt.rcParams['figure.figsize'] = (15.0, 15.0) # set default size of plots
plt.subplot(2,1,1) 
plt.plot(stats['loss_hist'])
plt.title('Loss History')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2,1,2)
plt.plot(stats['train_acc_hist'], label='train')
plt.plot(stats['val_acc_hist'], label='val')
plt.xlabel('Epoch')
plt.ylabel('Classfication Accuracies')
plt.legend()
plt.show()

# %%
print((net.predict(X_test) == y_test).mean())
# Out:
# 0.25

# %%
best_net = None # store the best model into this 
best_val= -1 #highest validation accuracy


hidden_unit = [200]
learn_rates = [7.6e-5]
regularizations = [0.0]
iterations = [600]

result = {}
best_stats = None

input_size = im_height * im_width * im_channel # 
output_size = 4 #4 class
for hidden in hidden_unit: 
    for learn in learn_rates:
        for r in regularizations:
            for iter in iterations:
                tune_net = TwoLayerNet(input_size,
                                       hidden_size=hidden,
                                       output_size=output_size,std=1e-3)
                stats = tune_net.train(X_train, y_train, X_val, y_val, 
                              num_iters=iter, batch_size=200, 
                              learning_rate=learn,learning_rate_decay=0.94, 
                              reg=r,  it_verbose = 100,verbose=True)
                train_acc = stats['train_acc_hist'][-1]#get last value 
                val_acc = stats['val_acc_hist'][-1]
                result[(hidden, learn)] = (train_acc, val_acc)
                #print log
                print('hs:',hidden,'learn:',learn,'reg',r,'iter',iter,'train-acc:',train_acc,'val_acc',val_acc)
                if(val_acc > best_val):
                    best_val = val_acc
                    #create best net
                    best_stats = stats
                    best_net = tune_net
                del tune_net
                del stats

print("Accuracy on Test set", (best_net.predict(X_test) == y_test).mean())
# Out:
# iteration: 0 / 600 | Loss: 1.499167
# iteration: 100 / 600 | Loss: 1.386295
# iteration: 200 / 600 | Loss: 1.386294
# iteration: 300 / 600 | Loss: 1.386294
# iteration: 400 / 600 | Loss: 1.386293
# iteration: 500 / 600 | Loss: 1.386295
# hs: 200 learn: 7.6e-05 reg 0.0 iter 600 train-acc: 0.305 val_acc 0.25
# Accuracy on Test set 0.25

# %%
# plot loss history and train/ validation accuracies history
plt.rcParams['figure.figsize'] = (15.0, 15.0) # set default size of plots
plt.subplot(2,1,1) 
plt.plot(best_stats['loss_hist'])
plt.title('Loss History')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2,1,2)
plt.plot(best_stats['train_acc_hist'], label='train')
plt.plot(best_stats['val_acc_hist'], label='val')
plt.xlabel('Epoch')
plt.ylabel('Classfication Accuracies')
plt.legend()
plt.show()

# %%
plt.hist(best_net.predict(X_test))
# Out:
# (array([  0.,   0.,   0.,   0.,   0., 200.,   0.,   0.,   0.,   0.]),
#  array([0.5, 0.6, 0.7, 0.8, 0.9, 1. , 1.1, 1.2, 1.3, 1.4, 1.5]),
#  <a list of 10 Patch objects>)
